# %%
# !pip install javalang graphviz esprima
# Out:
# Requirement already satisfied: javalang in /usr/local/lib/python3.12/dist-packages (0.13.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (0.21)
# Requirement already satisfied: esprima in /usr/local/lib/python3.12/dist-packages (4.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from javalang) (1.17.0)

# %%
import os
import ast
import javalang
from graphviz import Digraph

repo_path = "testFiles"
code_dict = {}

#Loades Py and Java Code and copies it in a dict
for filename in os.listdir(repo_path):
    filepath = os.path.join(repo_path, filename)
    if filename.endswith((".py", ".java")):
        with open(filepath, "r") as f:
            code_dict[filename] = f.read()

# Creates CallChian of Python Functions
class PythonCallVisitor(ast.NodeVisitor):
    def __init__(self, filename):
        self.filename = filename
        self.call_chain = {}

    def visit_FunctionDef(self, node):
        func_name = f"{self.filename}:{node.name}"
        calls = []
        for n in ast.walk(node):
            if isinstance(n, ast.Call):
                if isinstance(n.func, ast.Name):
                    calls.append(n.func.id)
                elif isinstance(n.func, ast.Attribute):
                    calls.append(n.func.attr)
        self.call_chain[func_name] = calls
        self.generic_visit(node)

#Creates CallChain of Java Functions by travesrsing the AST
class JavaCallVisitor:
    def __init__(self, filename):
        self.filename = filename
        self.call_chain = {}

    def visit(self, tree):
        for _, node in tree.filter(javalang.tree.MethodDeclaration):
            method_name = f"{self.filename}:{node.name}"
            calls = []
            if node.body:
                for path, subnode in node:
                    if isinstance(subnode, javalang.tree.MethodInvocation):
                        if subnode.qualifier:
                            calls.append(f"{subnode.qualifier}.{subnode.member}")
                        else:
                            calls.append(subnode.member)
            self.call_chain[method_name] = calls

#Creates DFD of Python File by traversing the AST
class PythonDFDVisitor(ast.NodeVisitor):
    def __init__(self, filename):
        self.filename = filename
        self.flows = []
        self.current_func = None

    def visit_FunctionDef(self, node):
        self.current_func = f"{self.filename}:{node.name}"
        for n in ast.walk(node):
            # Capture return values
            if isinstance(n, ast.Return):
                if isinstance(n.value, ast.Name):
                    data_repr = n.value.id
                elif isinstance(n.value, ast.Constant):
                    data_repr = repr(n.value.value)
                elif isinstance(n.value, ast.BinOp):
                    data_repr = ast.unparse(n.value)
                else:
                    data_repr = type(n.value).__name__
                self.flows.append((self.current_func, data_repr, "(returns)"))

            elif isinstance(n, ast.Call) and isinstance(n.func, ast.Name):
                callee = n.func.id
                for arg in n.args:
                    if isinstance(arg, ast.Name):
                        data_repr = arg.id
                    elif isinstance(arg, ast.Constant):
                        data_repr = repr(arg.value)
                    elif isinstance(arg, ast.BinOp):
                        data_repr = ast.unparse(arg)
                    else:
                        data_repr = type(arg).__name__
                    self.flows.append((self.current_func, data_repr, callee))

        self.generic_visit(node)


#Creates DFD of JAVA code by traversing AST
class JavaDFDExtractor:
    def __init__(self, filename):
        self.filename = filename
        self.flows = []

    def extract(self, tree):
        for type_decl in tree.types:
            if isinstance(type_decl, javalang.tree.ClassDeclaration):
                for method in type_decl.methods:
                    func_name = f"{self.filename}:{method.name}"
                    for path, node in method:
                        # Return statements
                        if isinstance(node, javalang.tree.ReturnStatement):
                            if node.expression:
                                if isinstance(node.expression, javalang.tree.MemberReference):
                                    data_repr = node.expression.member
                                elif isinstance(node.expression, javalang.tree.Literal):
                                    data_repr = node.expression.value
                                else:
                                    data_repr = type(node.expression).__name__
                                self.flows.append((func_name, data_repr, "(returns)"))

                        elif isinstance(node, javalang.tree.MethodInvocation):
                            callee = node.member
                            if node.arguments:
                                for arg in node.arguments:
                                    if isinstance(arg, javalang.tree.MemberReference):
                                        data_repr = arg.member
                                    elif isinstance(arg, javalang.tree.Literal):
                                        data_repr = arg.value
                                    else:
                                        data_repr = str(arg)
                                    self.flows.append((func_name, data_repr, callee))
                            else:
                                self.flows.append((func_name, "()", callee))

# %%
repo_call_chain = {}
repo_flows = []

#Creates Object of above classes and traverse the ast
for filename, code in code_dict.items():
      if filename.endswith(".py"):
          tree = ast.parse(code)
          call_visitor = PythonCallVisitor(filename)
          call_visitor.visit(tree)
          repo_call_chain.update(call_visitor.call_chain)
          dfd_visitor = PythonDFDVisitor(filename)
          dfd_visitor.visit(tree)
          repo_flows.extend(dfd_visitor.flows)

      elif filename.endswith(".java"):
          tree = javalang.parse.parse(code)
          call_visitor = JavaCallVisitor(filename)
          call_visitor.visit(tree)
          repo_call_chain.update(call_visitor.call_chain)
          dfd_extractor = JavaDFDExtractor(filename)
          dfd_extractor.extract(tree)
          repo_flows.extend(dfd_extractor.flows)

# %%
print("Data Flow (DFD):\n")
for src, data, dst in repo_flows:
    print(f"{src} --[{data}]--> {dst}")

#Creates edges from the repo_call_chain and renders the call-chain graph
dot_calls = Digraph(format="png", engine="sfdp")
dot_calls.attr(size="100,100", dpi="200")
for func, calls in repo_call_chain.items():
    func_name = func.split(":")[1]
    for called_func in calls:
        dot_calls.edge(func_name, called_func)
call_path = "call_chain"
dot_calls.render(call_path, cleanup=True)

#Creates edges from repo_flows and renders the DFD
dot_dfd = Digraph(format="png", engine="sfdp")
dot_dfd.attr(size="100,100", dpi = "200")
for src, data, dst in repo_flows:
    src_name = src.split(":")[1]
    dst_name = dst.split(":")[1] if ":" in dst else dst
    label = f"{data}"
    dot_dfd.edge(src_name, dst_name, label=label)
dfd_path = "DFD"
dot_dfd.render(dfd_path, cleanup=True)
# Out:
# Data Flow (DFD):
#
# SQLInjectionActivity.java:onCreate --["sqli"]--> openOrCreateDatabase
# SQLInjectionActivity.java:onCreate --[MODE_PRIVATE]--> openOrCreateDatabase
# SQLInjectionActivity.java:onCreate --[null]--> openOrCreateDatabase
# SQLInjectionActivity.java:onCreate --["DROP TABLE IF EXISTS sqliuser;"]--> execSQL
# SQLInjectionActivity.java:onCreate --["CREATE TABLE IF NOT EXISTS sqliuser(user VARCHAR, password VARCHAR, credit_card VARCHAR);"]--> execSQL
# SQLInjectionActivity.java:onCreate --["INSERT INTO sqliuser VALUES ('admin', 'passwd123', '1234567812345678');"]--> execSQL
# SQLInjectionActivity.java:onCreate --["INSERT INTO sqliuser VALUES ('diva', 'p@ssword', '1111222233334444');"]--> execSQL
# SQLInjectionActivity.java:onCreate --["INSERT INTO sqliuser VALUES ('john', 'password123', '5555666677778888');"]--> execSQL
# SQLInjectionActivity.java:onCreate --["Diva-sqli"]--> d
# SQLInjectionActivity.java:onCreate --[BinaryOperation(operandl=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="Error occurred while creating database for SQLI: "), operandr=MethodInvocation(arguments=[], member=getMessage, postfix_operators=[], prefix_operators=[], qualifier=e, selectors=[], type_arguments=None), operator=+)]--> d
# SQLInjectionActivity.java:onCreate --[()]--> getMessage
# SQLInjectionActivity.java:onCreate --[activity_sqlinjection]--> setContentView
# SQLInjectionActivity.java:search --[ivi1search]--> findViewById
# SQLInjectionActivity.java:search --[BinaryOperation(operandl=BinaryOperation(operandl=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="SELECT * FROM sqliuser WHERE user = '"), operandr=MethodInvocation(arguments=[], member=getText, postfix_operators=[], prefix_operators=[], qualifier=srchtxt, selectors=[MethodInvocation(arguments=[], member=toString, postfix_operators=None, prefix_operators=None, qualifier=None, selectors=None, type_arguments=None)], type_arguments=None), operator=+), operandr=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="'"), operator=+)]--> rawQuery
# SQLInjectionActivity.java:search --[null]--> rawQuery
# SQLInjectionActivity.java:search --[()]--> getText
# SQLInjectionActivity.java:search --[()]--> toString
# SQLInjectionActivity.java:search --[()]--> getCount
# SQLInjectionActivity.java:search --[()]--> moveToFirst
# SQLInjectionActivity.java:search --[()]--> moveToNext
# SQLInjectionActivity.java:search --[BinaryOperation(operandl=BinaryOperation(operandl=BinaryOperation(operandl=BinaryOperation(operandl=BinaryOperation(operandl=BinaryOperation(operandl=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="User: ("), operandr=MethodInvocation(arguments=[Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=0)], member=getString, postfix_operators=[], prefix_operators=[], qualifier=cr, selectors=[], type_arguments=None), operator=+), operandr=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=") pass: ("), operator=+), operandr=MethodInvocation(arguments=[Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=1)], member=getString, postfix_operators=[], prefix_operators=[], qualifier=cr, selectors=[], type_arguments=None), operator=+), operandr=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=") Credit card: ("), operator=+), operandr=MethodInvocation(arguments=[Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=2)], member=getString, postfix_operators=[], prefix_operators=[], qualifier=cr, selectors=[], type_arguments=None), operator=+), operandr=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=")\n"), operator=+)]--> append
# SQLInjectionActivity.java:search --[0]--> getString
# SQLInjectionActivity.java:search --[1]--> getString
# SQLInjectionActivity.java:search --[2]--> getString
# SQLInjectionActivity.java:search --[BinaryOperation(operandl=BinaryOperation(operandl=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="User: ("), operandr=MethodInvocation(arguments=[], member=getText, postfix_operators=[], prefix_operators=[], qualifier=srchtxt, selectors=[MethodInvocation(arguments=[], member=toString, postfix_operators=None, prefix_operators=None, qualifier=None, selectors=None, type_arguments=None)], type_arguments=None), operator=+), operandr=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=") not found"), operator=+)]--> append
# SQLInjectionActivity.java:search --[()]--> getText
# SQLInjectionActivity.java:search --[()]--> toString
# SQLInjectionActivity.java:search --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> makeText
# SQLInjectionActivity.java:search --[MethodInvocation(arguments=[], member=toString, postfix_operators=[], prefix_operators=[], qualifier=strb, selectors=[], type_arguments=None)]--> makeText
# SQLInjectionActivity.java:search --[LENGTH_SHORT]--> makeText
# SQLInjectionActivity.java:search --[()]--> show
# SQLInjectionActivity.java:search --[()]--> toString
# SQLInjectionActivity.java:search --["Diva-sqli"]--> d
# SQLInjectionActivity.java:search --[BinaryOperation(operandl=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="Error occurred while searching in database: "), operandr=MethodInvocation(arguments=[], member=getMessage, postfix_operators=[], prefix_operators=[], qualifier=e, selectors=[], type_arguments=None), operator=+)]--> d
# SQLInjectionActivity.java:search --[()]--> getMessage
# AccessControl3Activity.java:onCreate --[activity_access_control3]--> setContentView
# AccessControl3Activity.java:onCreate --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> getDefaultSharedPreferences
# AccessControl3Activity.java:onCreate --[MethodInvocation(arguments=[MemberReference(member=pkey, postfix_operators=[], prefix_operators=[], qualifier=R.string, selectors=[])], member=getString, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[], type_arguments=None)]--> getString
# AccessControl3Activity.java:onCreate --[""]--> getString
# AccessControl3Activity.java:onCreate --[pkey]--> getString
# AccessControl3Activity.java:onCreate --[()]--> isEmpty
# AccessControl3Activity.java:onCreate --[aci3viewbutton]--> findViewById
# AccessControl3Activity.java:onCreate --[VISIBLE]--> setVisibility
# AccessControl3Activity.java:addPin --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> getDefaultSharedPreferences
# AccessControl3Activity.java:addPin --[()]--> edit
# AccessControl3Activity.java:addPin --[aci3Pin]--> findViewById
# AccessControl3Activity.java:addPin --[()]--> getText
# AccessControl3Activity.java:addPin --[()]--> toString
# AccessControl3Activity.java:addPin --[()]--> isEmpty
# AccessControl3Activity.java:addPin --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> makeText
# AccessControl3Activity.java:addPin --["Please Enter a valid pin!"]--> makeText
# AccessControl3Activity.java:addPin --[LENGTH_SHORT]--> makeText
# AccessControl3Activity.java:addPin --[()]--> show
# AccessControl3Activity.java:addPin --[aci3viewbutton]--> findViewById
# AccessControl3Activity.java:addPin --[MethodInvocation(arguments=[MemberReference(member=pkey, postfix_operators=[], prefix_operators=[], qualifier=R.string, selectors=[])], member=getString, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[], type_arguments=None)]--> putString
# AccessControl3Activity.java:addPin --[pin]--> putString
# AccessControl3Activity.java:addPin --[pkey]--> getString
# AccessControl3Activity.java:addPin --[()]--> commit
# AccessControl3Activity.java:addPin --[()]--> getVisibility
# AccessControl3Activity.java:addPin --[VISIBLE]--> setVisibility
# AccessControl3Activity.java:addPin --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> makeText
# AccessControl3Activity.java:addPin --["PIN Created successfully. Private notes are now protected with PIN"]--> makeText
# AccessControl3Activity.java:addPin --[LENGTH_SHORT]--> makeText
# AccessControl3Activity.java:addPin --[()]--> show
# AccessControl3Activity.java:goToNotes --[i]--> startActivity
# LogActivity.java:onCreate --[activity_log]--> setContentView
# LogActivity.java:checkout --[ccText]--> findViewById
# LogActivity.java:checkout --[MethodInvocation(arguments=[], member=getText, postfix_operators=[], prefix_operators=[], qualifier=cctxt, selectors=[MethodInvocation(arguments=[], member=toString, postfix_operators=None, prefix_operators=None, qualifier=None, selectors=None, type_arguments=None)], type_arguments=None)]--> processCC
# LogActivity.java:checkout --[()]--> getText
# LogActivity.java:checkout --[()]--> toString
# LogActivity.java:checkout --["diva-log"]--> e
# LogActivity.java:checkout --[BinaryOperation(operandl=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="Error while processing transaction with credit card: "), operandr=MethodInvocation(arguments=[], member=getText, postfix_operators=[], prefix_operators=[], qualifier=cctxt, selectors=[MethodInvocation(arguments=[], member=toString, postfix_operators=None, prefix_operators=None, qualifier=None, selectors=None, type_arguments=None)], type_arguments=None), operator=+)]--> e
# LogActivity.java:checkout --[()]--> getText
# LogActivity.java:checkout --[()]--> toString
# LogActivity.java:checkout --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> makeText
# LogActivity.java:checkout --["An error occured. Please try again later"]--> makeText
# LogActivity.java:checkout --[LENGTH_SHORT]--> makeText
# LogActivity.java:checkout --[()]--> show
# AccessControl1Activity.java:onCreate --[activity_access_control1]--> setContentView
# AccessControl1Activity.java:viewAPICredentials --["jakhar.aseem.diva.action.VIEW_CREDS"]--> setAction
# AccessControl1Activity.java:viewAPICredentials --[MethodInvocation(arguments=[], member=getPackageManager, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[], type_arguments=None)]--> resolveActivity
# AccessControl1Activity.java:viewAPICredentials --[()]--> getPackageManager
# AccessControl1Activity.java:viewAPICredentials --[i]--> startActivity
# AccessControl1Activity.java:viewAPICredentials --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> makeText
# AccessControl1Activity.java:viewAPICredentials --["Error while getting API details"]--> makeText
# AccessControl1Activity.java:viewAPICredentials --[LENGTH_SHORT]--> makeText
# AccessControl1Activity.java:viewAPICredentials --[()]--> show
# AccessControl1Activity.java:viewAPICredentials --["Diva-aci1"]--> e
# AccessControl1Activity.java:viewAPICredentials --["Couldn't resolve the Intent VIEW_CREDS to our activity"]--> e
# NotesProvider.java:delete --[uri]--> match
# NotesProvider.java:delete --[TABLE]--> delete
# NotesProvider.java:delete --[selection]--> delete
# NotesProvider.java:delete --[selectionArgs]--> delete
# NotesProvider.java:delete --[()]--> getLastPathSegment
# NotesProvider.java:delete --[TABLE]--> delete
# NotesProvider.java:delete --[BinaryOperation(operandl=BinaryOperation(operandl=BinaryOperation(operandl=MemberReference(member=C_ID, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[]), operandr=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=" = "), operator=+), operandr=MemberReference(member=id, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[]), operator=+), operandr=TernaryExpression(condition=MethodInvocation(arguments=[MemberReference(member=selection, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[])], member=isEmpty, postfix_operators=[], prefix_operators=['!'], qualifier=TextUtils, selectors=[], type_arguments=None), if_false=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=""), if_true=BinaryOperation(operandl=BinaryOperation(operandl=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=" AND ("), operandr=MemberReference(member=selection, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[]), operator=+), operandr=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=')'), operator=+)), operator=+)]--> delete
# NotesProvider.java:delete --[selectionArgs]--> delete
# NotesProvider.java:delete --[selection]--> isEmpty
# NotesProvider.java:delete --[()]--> getContext
# NotesProvider.java:delete --[()]--> getContentResolver
# NotesProvider.java:delete --[uri]--> notifyChange
# NotesProvider.java:delete --[null]--> notifyChange
# NotesProvider.java:delete --[count]--> (returns)
# NotesProvider.java:getType --[uri]--> match
# NotesProvider.java:getType --["vnd.android.cursor.dir/vnd.jakhar.notes"]--> (returns)
# NotesProvider.java:getType --["vnd.android.cursor.item/vnd.jakhar.notes"]--> (returns)
# NotesProvider.java:insert --[TABLE]--> insert
# NotesProvider.java:insert --[""]--> insert
# NotesProvider.java:insert --[values]--> insert
# NotesProvider.java:insert --[CONTENT_URI]--> withAppendedId
# NotesProvider.java:insert --[row]--> withAppendedId
# NotesProvider.java:insert --[()]--> getContext
# NotesProvider.java:insert --[()]--> getContentResolver
# NotesProvider.java:insert --[newUri]--> notifyChange
# NotesProvider.java:insert --[null]--> notifyChange
# NotesProvider.java:insert --[newUri]--> (returns)
# NotesProvider.java:onCreate --[()]--> getContext
# NotesProvider.java:onCreate --[()]--> getWritableDatabase
# NotesProvider.java:onCreate --[false]--> (returns)
# NotesProvider.java:onCreate --[true]--> (returns)
# NotesProvider.java:query --[TABLE]--> setTables
# NotesProvider.java:query --[uri]--> match
# NotesProvider.java:query --[BinaryOperation(operandl=BinaryOperation(operandl=MemberReference(member=C_ID, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[]), operandr=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="="), operator=+), operandr=MethodInvocation(arguments=[], member=getLastPathSegment, postfix_operators=[], prefix_operators=[], qualifier=uri, selectors=[], type_arguments=None), operator=+)]--> appendWhere
# NotesProvider.java:query --[()]--> getLastPathSegment
# NotesProvider.java:query --[mDB]--> query
# NotesProvider.java:query --[projection]--> query
# NotesProvider.java:query --[selection]--> query
# NotesProvider.java:query --[selectionArgs]--> query
# NotesProvider.java:query --[null]--> query
# NotesProvider.java:query --[null]--> query
# NotesProvider.java:query --[sortOrder]--> query
# NotesProvider.java:query --[MethodInvocation(arguments=[], member=getContext, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[MethodInvocation(arguments=[], member=getContentResolver, postfix_operators=None, prefix_operators=None, qualifier=None, selectors=None, type_arguments=None)], type_arguments=None)]--> setNotificationUri
# NotesProvider.java:query --[uri]--> setNotificationUri
# NotesProvider.java:query --[()]--> getContext
# NotesProvider.java:query --[()]--> getContentResolver
# NotesProvider.java:query --[cursor]--> (returns)
# NotesProvider.java:update --[uri]--> match
# NotesProvider.java:update --[TABLE]--> update
# NotesProvider.java:update --[values]--> update
# NotesProvider.java:update --[selection]--> update
# NotesProvider.java:update --[selectionArgs]--> update
# NotesProvider.java:update --[TABLE]--> update
# NotesProvider.java:update --[values]--> update
# NotesProvider.java:update --[BinaryOperation(operandl=BinaryOperation(operandl=BinaryOperation(operandl=MemberReference(member=C_ID, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[]), operandr=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=" = "), operator=+), operandr=MethodInvocation(arguments=[], member=getLastPathSegment, postfix_operators=[], prefix_operators=[], qualifier=uri, selectors=[], type_arguments=None), operator=+), operandr=TernaryExpression(condition=MethodInvocation(arguments=[MemberReference(member=selection, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[])], member=isEmpty, postfix_operators=[], prefix_operators=['!'], qualifier=TextUtils, selectors=[], type_arguments=None), if_false=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=""), if_true=BinaryOperation(operandl=BinaryOperation(operandl=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=" AND ("), operandr=MemberReference(member=selection, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[]), operator=+), operandr=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=')'), operator=+)), operator=+)]--> update
# NotesProvider.java:update --[selectionArgs]--> update
# NotesProvider.java:update --[()]--> getLastPathSegment
# NotesProvider.java:update --[selection]--> isEmpty
# NotesProvider.java:update --[()]--> getContext
# NotesProvider.java:update --[()]--> getContentResolver
# NotesProvider.java:update --[uri]--> notifyChange
# NotesProvider.java:update --[null]--> notifyChange
# NotesProvider.java:update --[count]--> (returns)
# AccessControl3NotesActivity.java:onCreate --[activity_access_control3_notes]--> setContentView
# AccessControl3NotesActivity.java:accessNotes --[aci3notesPinText]--> findViewById
# AccessControl3NotesActivity.java:accessNotes --[aci3naccessbutton]--> findViewById
# AccessControl3NotesActivity.java:accessNotes --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> getDefaultSharedPreferences
# AccessControl3NotesActivity.java:accessNotes --[MethodInvocation(arguments=[MemberReference(member=pkey, postfix_operators=[], prefix_operators=[], qualifier=R.string, selectors=[])], member=getString, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[], type_arguments=None)]--> getString
# AccessControl3NotesActivity.java:accessNotes --[""]--> getString
# AccessControl3NotesActivity.java:accessNotes --[pkey]--> getString
# AccessControl3NotesActivity.java:accessNotes --[()]--> getText
# AccessControl3NotesActivity.java:accessNotes --[()]--> toString
# AccessControl3NotesActivity.java:accessNotes --[pin]--> equals
# AccessControl3NotesActivity.java:accessNotes --[aci3nlistView]--> findViewById
# AccessControl3NotesActivity.java:accessNotes --[()]--> getContentResolver
# AccessControl3NotesActivity.java:accessNotes --[CONTENT_URI]--> query
# AccessControl3NotesActivity.java:accessNotes --[ArrayCreator(dimensions=[None], initializer=ArrayInitializer(initializers=[Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="_id"), Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="title"), Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="note")]), postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], type=ReferenceType(arguments=None, dimensions=None, name=String, sub_type=None))]--> query
# AccessControl3NotesActivity.java:accessNotes --[null]--> query
# AccessControl3NotesActivity.java:accessNotes --[null]--> query
# AccessControl3NotesActivity.java:accessNotes --[null]--> query
# AccessControl3NotesActivity.java:accessNotes --[adapter]--> setAdapter
# AccessControl3NotesActivity.java:accessNotes --[INVISIBLE]--> setVisibility
# AccessControl3NotesActivity.java:accessNotes --[INVISIBLE]--> setVisibility
# AccessControl3NotesActivity.java:accessNotes --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> makeText
# AccessControl3NotesActivity.java:accessNotes --["Please Enter a valid pin!"]--> makeText
# AccessControl3NotesActivity.java:accessNotes --[LENGTH_SHORT]--> makeText
# AccessControl3NotesActivity.java:accessNotes --[()]--> show
# InputValidation3Activity.java:onCreate --[activity_input_validation3]--> setContentView
# InputValidation3Activity.java:push --[ivi3CodeText]--> findViewById
# InputValidation3Activity.java:push --[MethodInvocation(arguments=[], member=getText, postfix_operators=[], prefix_operators=[], qualifier=cTxt, selectors=[MethodInvocation(arguments=[], member=toString, postfix_operators=None, prefix_operators=None, qualifier=None, selectors=None, type_arguments=None)], type_arguments=None)]--> initiateLaunchSequence
# InputValidation3Activity.java:push --[()]--> getText
# InputValidation3Activity.java:push --[()]--> toString
# InputValidation3Activity.java:push --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> makeText
# InputValidation3Activity.java:push --["Launching in T - 10 ..."]--> makeText
# InputValidation3Activity.java:push --[LENGTH_SHORT]--> makeText
# InputValidation3Activity.java:push --[()]--> show
# InputValidation3Activity.java:push --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> makeText
# InputValidation3Activity.java:push --["Access denied!"]--> makeText
# InputValidation3Activity.java:push --[LENGTH_SHORT]--> makeText
# InputValidation3Activity.java:push --[()]--> show
# APICredsActivity.java:onCreate --[activity_apicreds]--> setContentView
# APICredsActivity.java:onCreate --[apicTextView]--> findViewById
# APICredsActivity.java:onCreate --[apidetails]--> setText
# HardcodeActivity.java:onCreate --[activity_hardcode]--> setContentView
# HardcodeActivity.java:access --[hcKey]--> findViewById
# HardcodeActivity.java:access --[()]--> getText
# HardcodeActivity.java:access --[()]--> toString
# HardcodeActivity.java:access --["vendorsecretkey"]--> equals
# HardcodeActivity.java:access --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> makeText
# HardcodeActivity.java:access --["Access granted! See you on the other side :)"]--> makeText
# HardcodeActivity.java:access --[LENGTH_SHORT]--> makeText
# HardcodeActivity.java:access --[()]--> show
# HardcodeActivity.java:access --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> makeText
# HardcodeActivity.java:access --["Access denied! See you in hell :D"]--> makeText
# HardcodeActivity.java:access --[LENGTH_SHORT]--> makeText
# HardcodeActivity.java:access --[()]--> show
# APICreds2Activity.java:onCreate --[activity_apicreds2]--> setContentView
# APICreds2Activity.java:onCreate --[apic2TextView]--> findViewById
# APICreds2Activity.java:onCreate --[aci2pinText]--> findViewById
# APICreds2Activity.java:onCreate --[aci2button]--> findViewById
# APICreds2Activity.java:onCreate --[()]--> getIntent
# APICreds2Activity.java:onCreate --[MethodInvocation(arguments=[MemberReference(member=chk_pin, postfix_operators=[], prefix_operators=[], qualifier=R.string, selectors=[])], member=getString, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[], type_arguments=None)]--> getBooleanExtra
# APICreds2Activity.java:onCreate --[true]--> getBooleanExtra
# APICreds2Activity.java:onCreate --[chk_pin]--> getString
# APICreds2Activity.java:onCreate --[apidetails]--> setText
# APICreds2Activity.java:onCreate --["Register yourself at http://payatu.com to get your PIN and then login with that PIN!"]--> setText
# APICreds2Activity.java:onCreate --[VISIBLE]--> setVisibility
# APICreds2Activity.java:onCreate --[VISIBLE]--> setVisibility
# APICreds2Activity.java:viewCreds --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> makeText
# APICreds2Activity.java:viewCreds --["Invalid PIN. Please try again"]--> makeText
# APICreds2Activity.java:viewCreds --[LENGTH_SHORT]--> makeText
# APICreds2Activity.java:viewCreds --[()]--> show
# AccessControl2Activity.java:onCreate --[activity_access_control2]--> setContentView
# AccessControl2Activity.java:viewAPICredentials --[aci2rbregnow]--> findViewById
# AccessControl2Activity.java:viewAPICredentials --[()]--> isChecked
# AccessControl2Activity.java:viewAPICredentials --["jakhar.aseem.diva.action.VIEW_CREDS2"]--> setAction
# AccessControl2Activity.java:viewAPICredentials --[MethodInvocation(arguments=[MemberReference(member=chk_pin, postfix_operators=[], prefix_operators=[], qualifier=R.string, selectors=[])], member=getString, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[], type_arguments=None)]--> putExtra
# AccessControl2Activity.java:viewAPICredentials --[chk_pin]--> putExtra
# AccessControl2Activity.java:viewAPICredentials --[chk_pin]--> getString
# AccessControl2Activity.java:viewAPICredentials --[MethodInvocation(arguments=[], member=getPackageManager, postfix_operators=[], prefix_operators=[], qualifier=, selectors=[], type_arguments=None)]--> resolveActivity
# AccessControl2Activity.java:viewAPICredentials --[()]--> getPackageManager
# AccessControl2Activity.java:viewAPICredentials --[i]--> startActivity
# AccessControl2Activity.java:viewAPICredentials --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> makeText
# AccessControl2Activity.java:viewAPICredentials --["Error while getting Tveeter API details"]--> makeText
# AccessControl2Activity.java:viewAPICredentials --[LENGTH_SHORT]--> makeText
# AccessControl2Activity.java:viewAPICredentials --[()]--> show
# AccessControl2Activity.java:viewAPICredentials --["Diva-aci1"]--> e
# AccessControl2Activity.java:viewAPICredentials --["Couldn't resolve the Intent VIEW_CREDS2 to our activity"]--> e
# InputValidation2URISchemeActivity.java:onCreate --[activity_input_validation2_urischeme]--> setContentView
# InputValidation2URISchemeActivity.java:onCreate --[ivi2wview]--> findViewById
# InputValidation2URISchemeActivity.java:onCreate --[()]--> getSettings
# InputValidation2URISchemeActivity.java:onCreate --[true]--> setJavaScriptEnabled
# InputValidation2URISchemeActivity.java:get --[ivi2uri]--> findViewById
# InputValidation2URISchemeActivity.java:get --[ivi2wview]--> findViewById
# InputValidation2URISchemeActivity.java:get --[MethodInvocation(arguments=[], member=getText, postfix_operators=[], prefix_operators=[], qualifier=uriText, selectors=[MethodInvocation(arguments=[], member=toString, postfix_operators=None, prefix_operators=None, qualifier=None, selectors=None, type_arguments=None)], type_arguments=None)]--> loadUrl
# InputValidation2URISchemeActivity.java:get --[()]--> getText
# InputValidation2URISchemeActivity.java:get --[()]--> toString
# InsecureDataStorage4Activity.java:onCreate --[activity_insecure_data_storage4]--> setContentView
# InsecureDataStorage4Activity.java:saveCredentials --[ids4Usr]--> findViewById
# InsecureDataStorage4Activity.java:saveCredentials --[ids4Pwd]--> findViewById
# InsecureDataStorage4Activity.java:saveCredentials --[()]--> getExternalStorageDirectory
# InsecureDataStorage4Activity.java:saveCredentials --[()]--> getAbsolutePath
# InsecureDataStorage4Activity.java:saveCredentials --[true]--> setReadable
# InsecureDataStorage4Activity.java:saveCredentials --[true]--> setWritable
# InsecureDataStorage4Activity.java:saveCredentials --[BinaryOperation(operandl=BinaryOperation(operandl=BinaryOperation(operandl=MethodInvocation(arguments=[], member=getText, postfix_operators=[], prefix_operators=[], qualifier=usr, selectors=[MethodInvocation(arguments=[], member=toString, postfix_operators=None, prefix_operators=None, qualifier=None, selectors=None, type_arguments=None)], type_arguments=None), operandr=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=":"), operator=+), operandr=MethodInvocation(arguments=[], member=getText, postfix_operators=[], prefix_operators=[], qualifier=pwd, selectors=[MethodInvocation(arguments=[], member=toString, postfix_operators=None, prefix_operators=None, qualifier=None, selectors=None, type_arguments=None)], type_arguments=None), operator=+), operandr=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="\n"), operator=+)]--> write
# InsecureDataStorage4Activity.java:saveCredentials --[()]--> getText
# InsecureDataStorage4Activity.java:saveCredentials --[()]--> toString
# InsecureDataStorage4Activity.java:saveCredentials --[()]--> getText
# InsecureDataStorage4Activity.java:saveCredentials --[()]--> toString
# InsecureDataStorage4Activity.java:saveCredentials --[()]--> close
# InsecureDataStorage4Activity.java:saveCredentials --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> makeText
# InsecureDataStorage4Activity.java:saveCredentials --["3rd party credentials saved successfully!"]--> makeText
# InsecureDataStorage4Activity.java:saveCredentials --[LENGTH_SHORT]--> makeText
# InsecureDataStorage4Activity.java:saveCredentials --[()]--> show
# InsecureDataStorage4Activity.java:saveCredentials --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> makeText
# InsecureDataStorage4Activity.java:saveCredentials --["File error occurred"]--> makeText
# InsecureDataStorage4Activity.java:saveCredentials --[LENGTH_SHORT]--> makeText
# InsecureDataStorage4Activity.java:saveCredentials --[()]--> show
# InsecureDataStorage4Activity.java:saveCredentials --["Diva"]--> d
# InsecureDataStorage4Activity.java:saveCredentials --[BinaryOperation(operandl=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="File error: "), operandr=MethodInvocation(arguments=[], member=getMessage, postfix_operators=[], prefix_operators=[], qualifier=e, selectors=[], type_arguments=None), operator=+)]--> d
# InsecureDataStorage4Activity.java:saveCredentials --[()]--> getMessage
# InsecureDataStorage3Activity.java:onCreate --[activity_insecure_data_storage3]--> setContentView
# InsecureDataStorage3Activity.java:saveCredentials --[ids3Usr]--> findViewById
# InsecureDataStorage3Activity.java:saveCredentials --[ids3Pwd]--> findViewById
# InsecureDataStorage3Activity.java:saveCredentials --[()]--> getApplicationInfo
# InsecureDataStorage3Activity.java:saveCredentials --["uinfo"]--> createTempFile
# InsecureDataStorage3Activity.java:saveCredentials --["tmp"]--> createTempFile
# InsecureDataStorage3Activity.java:saveCredentials --[ddir]--> createTempFile
# InsecureDataStorage3Activity.java:saveCredentials --[true]--> setReadable
# InsecureDataStorage3Activity.java:saveCredentials --[true]--> setWritable
# InsecureDataStorage3Activity.java:saveCredentials --[BinaryOperation(operandl=BinaryOperation(operandl=BinaryOperation(operandl=MethodInvocation(arguments=[], member=getText, postfix_operators=[], prefix_operators=[], qualifier=usr, selectors=[MethodInvocation(arguments=[], member=toString, postfix_operators=None, prefix_operators=None, qualifier=None, selectors=None, type_arguments=None)], type_arguments=None), operandr=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value=":"), operator=+), operandr=MethodInvocation(arguments=[], member=getText, postfix_operators=[], prefix_operators=[], qualifier=pwd, selectors=[MethodInvocation(arguments=[], member=toString, postfix_operators=None, prefix_operators=None, qualifier=None, selectors=None, type_arguments=None)], type_arguments=None), operator=+), operandr=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="\n"), operator=+)]--> write
# InsecureDataStorage3Activity.java:saveCredentials --[()]--> getText
# InsecureDataStorage3Activity.java:saveCredentials --[()]--> toString
# InsecureDataStorage3Activity.java:saveCredentials --[()]--> getText
# InsecureDataStorage3Activity.java:saveCredentials --[()]--> toString
# InsecureDataStorage3Activity.java:saveCredentials --[()]--> close
# InsecureDataStorage3Activity.java:saveCredentials --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> makeText
# InsecureDataStorage3Activity.java:saveCredentials --["3rd party credentials saved successfully!"]--> makeText
# InsecureDataStorage3Activity.java:saveCredentials --[LENGTH_SHORT]--> makeText
# InsecureDataStorage3Activity.java:saveCredentials --[()]--> show
# InsecureDataStorage3Activity.java:saveCredentials --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> makeText
# InsecureDataStorage3Activity.java:saveCredentials --["File error occurred"]--> makeText
# InsecureDataStorage3Activity.java:saveCredentials --[LENGTH_SHORT]--> makeText
# InsecureDataStorage3Activity.java:saveCredentials --[()]--> show
# InsecureDataStorage3Activity.java:saveCredentials --["Diva"]--> d
# InsecureDataStorage3Activity.java:saveCredentials --[BinaryOperation(operandl=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="File error: "), operandr=MethodInvocation(arguments=[], member=getMessage, postfix_operators=[], prefix_operators=[], qualifier=e, selectors=[], type_arguments=None), operator=+)]--> d
# InsecureDataStorage3Activity.java:saveCredentials --[()]--> getMessage
# InsecureDataStorage1Activity.java:onCreate --[activity_insecure_data_storage1]--> setContentView
# InsecureDataStorage1Activity.java:saveCredentials --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> getDefaultSharedPreferences
# InsecureDataStorage1Activity.java:saveCredentials --[()]--> edit
# InsecureDataStorage1Activity.java:saveCredentials --[ids1Usr]--> findViewById
# InsecureDataStorage1Activity.java:saveCredentials --[ids1Pwd]--> findViewById
# InsecureDataStorage1Activity.java:saveCredentials --["user"]--> putString
# InsecureDataStorage1Activity.java:saveCredentials --[MethodInvocation(arguments=[], member=getText, postfix_operators=[], prefix_operators=[], qualifier=usr, selectors=[MethodInvocation(arguments=[], member=toString, postfix_operators=None, prefix_operators=None, qualifier=None, selectors=None, type_arguments=None)], type_arguments=None)]--> putString
# InsecureDataStorage1Activity.java:saveCredentials --[()]--> getText
# InsecureDataStorage1Activity.java:saveCredentials --[()]--> toString
# InsecureDataStorage1Activity.java:saveCredentials --["password"]--> putString
# InsecureDataStorage1Activity.java:saveCredentials --[MethodInvocation(arguments=[], member=getText, postfix_operators=[], prefix_operators=[], qualifier=pwd, selectors=[MethodInvocation(arguments=[], member=toString, postfix_operators=None, prefix_operators=None, qualifier=None, selectors=None, type_arguments=None)], type_arguments=None)]--> putString
# InsecureDataStorage1Activity.java:saveCredentials --[()]--> getText
# InsecureDataStorage1Activity.java:saveCredentials --[()]--> toString
# InsecureDataStorage1Activity.java:saveCredentials --[()]--> commit
# InsecureDataStorage1Activity.java:saveCredentials --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> makeText
# InsecureDataStorage1Activity.java:saveCredentials --["3rd party credentials saved successfully!"]--> makeText
# InsecureDataStorage1Activity.java:saveCredentials --[LENGTH_SHORT]--> makeText
# InsecureDataStorage1Activity.java:saveCredentials --[()]--> show
# InsecureDataStorage2Activity.java:onCreate --["ids2"]--> openOrCreateDatabase
# InsecureDataStorage2Activity.java:onCreate --[MODE_PRIVATE]--> openOrCreateDatabase
# InsecureDataStorage2Activity.java:onCreate --[null]--> openOrCreateDatabase
# InsecureDataStorage2Activity.java:onCreate --["CREATE TABLE IF NOT EXISTS myuser(user VARCHAR, password VARCHAR);"]--> execSQL
# InsecureDataStorage2Activity.java:onCreate --["Diva"]--> d
# InsecureDataStorage2Activity.java:onCreate --[BinaryOperation(operandl=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="Error occurred while creating database: "), operandr=MethodInvocation(arguments=[], member=getMessage, postfix_operators=[], prefix_operators=[], qualifier=e, selectors=[], type_arguments=None), operator=+)]--> d
# InsecureDataStorage2Activity.java:onCreate --[()]--> getMessage
# InsecureDataStorage2Activity.java:onCreate --[activity_insecure_data_storage2]--> setContentView
# InsecureDataStorage2Activity.java:saveCredentials --[ids2Usr]--> findViewById
# InsecureDataStorage2Activity.java:saveCredentials --[ids2Pwd]--> findViewById
# InsecureDataStorage2Activity.java:saveCredentials --[BinaryOperation(operandl=BinaryOperation(operandl=BinaryOperation(operandl=BinaryOperation(operandl=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="INSERT INTO myuser VALUES ('"), operandr=MethodInvocation(arguments=[], member=getText, postfix_operators=[], prefix_operators=[], qualifier=usr, selectors=[MethodInvocation(arguments=[], member=toString, postfix_operators=None, prefix_operators=None, qualifier=None, selectors=None, type_arguments=None)], type_arguments=None), operator=+), operandr=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="', '"), operator=+), operandr=MethodInvocation(arguments=[], member=getText, postfix_operators=[], prefix_operators=[], qualifier=pwd, selectors=[MethodInvocation(arguments=[], member=toString, postfix_operators=None, prefix_operators=None, qualifier=None, selectors=None, type_arguments=None)], type_arguments=None), operator=+), operandr=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="');"), operator=+)]--> execSQL
# InsecureDataStorage2Activity.java:saveCredentials --[()]--> getText
# InsecureDataStorage2Activity.java:saveCredentials --[()]--> toString
# InsecureDataStorage2Activity.java:saveCredentials --[()]--> getText
# InsecureDataStorage2Activity.java:saveCredentials --[()]--> toString
# InsecureDataStorage2Activity.java:saveCredentials --[()]--> close
# InsecureDataStorage2Activity.java:saveCredentials --["Diva"]--> d
# InsecureDataStorage2Activity.java:saveCredentials --[BinaryOperation(operandl=Literal(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[], value="Error occurred while inserting into database: "), operandr=MethodInvocation(arguments=[], member=getMessage, postfix_operators=[], prefix_operators=[], qualifier=e, selectors=[], type_arguments=None), operator=+)]--> d
# InsecureDataStorage2Activity.java:saveCredentials --[()]--> getMessage
# InsecureDataStorage2Activity.java:saveCredentials --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> makeText
# InsecureDataStorage2Activity.java:saveCredentials --["3rd party credentials saved successfully!"]--> makeText
# InsecureDataStorage2Activity.java:saveCredentials --[LENGTH_SHORT]--> makeText
# InsecureDataStorage2Activity.java:saveCredentials --[()]--> show
# MainActivity.java:onCreate --[activity_main]--> setContentView
# MainActivity.java:onCreate --[toolbar]--> findViewById
# MainActivity.java:onCreate --[toolbar]--> setSupportActionBar
# MainActivity.java:onCreateOptionsMenu --[()]--> getMenuInflater
# MainActivity.java:onCreateOptionsMenu --[menu_main]--> inflate
# MainActivity.java:onCreateOptionsMenu --[menu]--> inflate
# MainActivity.java:onCreateOptionsMenu --[true]--> (returns)
# MainActivity.java:onOptionsItemSelected --[()]--> getItemId
# MainActivity.java:onOptionsItemSelected --[true]--> (returns)
# MainActivity.java:onOptionsItemSelected --[SuperMethodInvocation]--> (returns)
# MainActivity.java:startChallenge --[d1button]--> findViewById
# MainActivity.java:startChallenge --[i]--> startActivity
# MainActivity.java:startChallenge --[d2button]--> findViewById
# MainActivity.java:startChallenge --[i]--> startActivity
# MainActivity.java:startChallenge --[d3button]--> findViewById
# MainActivity.java:startChallenge --[i]--> startActivity
# MainActivity.java:startChallenge --[d4button]--> findViewById
# MainActivity.java:startChallenge --[i]--> startActivity
# MainActivity.java:startChallenge --[d5button]--> findViewById
# MainActivity.java:startChallenge --[i]--> startActivity
# MainActivity.java:startChallenge --[d6button]--> findViewById
# MainActivity.java:startChallenge --[i]--> startActivity
# MainActivity.java:startChallenge --[d7button]--> findViewById
# MainActivity.java:startChallenge --[i]--> startActivity
# MainActivity.java:startChallenge --[d8button]--> findViewById
# MainActivity.java:startChallenge --[i]--> startActivity
# MainActivity.java:startChallenge --[d9button]--> findViewById
# MainActivity.java:startChallenge --[i]--> startActivity
# MainActivity.java:startChallenge --[d10button]--> findViewById
# MainActivity.java:startChallenge --[i]--> startActivity
# MainActivity.java:startChallenge --[d11button]--> findViewById
# MainActivity.java:startChallenge --[i]--> startActivity
# MainActivity.java:startChallenge --[d12button]--> findViewById
# MainActivity.java:startChallenge --[i]--> startActivity
# MainActivity.java:startChallenge --[d13button]--> findViewById
# MainActivity.java:startChallenge --[i]--> startActivity
# Hardcode2Activity.java:onCreate --[activity_hardcode2]--> setContentView
# Hardcode2Activity.java:access --[hc2Key]--> findViewById
# Hardcode2Activity.java:access --[MethodInvocation(arguments=[], member=getText, postfix_operators=[], prefix_operators=[], qualifier=hckey, selectors=[MethodInvocation(arguments=[], member=toString, postfix_operators=None, prefix_operators=None, qualifier=None, selectors=None, type_arguments=None)], type_arguments=None)]--> access
# Hardcode2Activity.java:access --[()]--> getText
# Hardcode2Activity.java:access --[()]--> toString
# Hardcode2Activity.java:access --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> makeText
# Hardcode2Activity.java:access --["Access granted! See you on the other side :)"]--> makeText
# Hardcode2Activity.java:access --[LENGTH_SHORT]--> makeText
# Hardcode2Activity.java:access --[()]--> show
# Hardcode2Activity.java:access --[This(postfix_operators=[], prefix_operators=[], qualifier=None, selectors=[])]--> makeText
# Hardcode2Activity.java:access --["Access denied! See you in hell :D"]--> makeText
# Hardcode2Activity.java:access --[LENGTH_SHORT]--> makeText
# Hardcode2Activity.java:access --[()]--> show
# 'DFD.png'

# %%
import re

# Extract method/function code based on keywords
def extract_function_code(code, func_name, language):
    if language == "python":
        pattern = rf"def\s+{re.escape(func_name)}\s*\([^)]*\)\s*:[\s\S]*?(?=\ndef\s|\nclass\s|$)"
    elif language == "java":
        pattern = rf"\b{re.escape(func_name)}\s*\([^)]*\)\s*\{{[\s\S]*?\}}"

    match = re.search(pattern, code)
    return match.group(0).strip() if match else ""

# %%
#Determines the level of abstraction of each function in call chain based on the incoming and outgoing nodes
def analyze_call_layers(repo_call_chain):
    incoming_count = {func: 0 for func in repo_call_chain}
    outgoing_count = {func: len(calls) for func, calls in repo_call_chain.items()}

    for func, calls in repo_call_chain.items():
        for called in calls:
            for target_func in repo_call_chain:
                if target_func.endswith(f":{called}"):
                    incoming_count[target_func] += 1

    layer_map = {}
    for func in repo_call_chain:
        incoming = incoming_count[func]
        outgoing = outgoing_count[func]

        if incoming == 0 and outgoing > 0:
            layer_map[func] = "High-level (Application)"
        elif incoming > 0 and outgoing > 0:
            layer_map[func] = "Mid-level (Logic)"
        elif incoming > 0 and outgoing == 0:
            layer_map[func] = "Low-level (Utility)"
        else:
            layer_map[func] = "Isolated/Helper"

    return layer_map

# %%
#Extracts arguments passed from function1 to function2 in py using AST
def arguments_from_python(code: str, caller_name: str, callee_name: str):

    tree = ast.parse(code)
    class CallVisitor(ast.NodeVisitor):
        def __init__(self):
            self.args_found = []

        def visit_FunctionDef(self, node):
            if node.name == caller_name:
                for n in ast.walk(node):
                    if isinstance(n, ast.Call) and isinstance(n.func, ast.Name) and n.func.id == callee_name:
                        arg_values = []
                        for arg in n.args:
                            if isinstance(arg, ast.Constant):
                                arg_values.append(repr(arg.value))
                            elif isinstance(arg, ast.Name):
                                arg_values.append(arg.id)
                            else:
                                arg_values.append(ast.unparse(arg))

                        self.args_found.append(arg_values)

    visitor = CallVisitor()
    visitor.visit(tree)
    return visitor.args_found

# %%
import javalang

#Extracts arguments passed from method1 to method2 in java from ast
def arguments_from_java(code: str, caller_name: str, callee_name: str):

    tree = javalang.parse.parse(code)


    args_found = []

    for _, node in tree.filter(javalang.tree.MethodDeclaration):
        if node.name == caller_name:
            for path, call in node.filter(javalang.tree.MethodInvocation):
                if call.member == callee_name:
                    arg_values = []
                    for arg in call.arguments:
                        if isinstance(arg, javalang.tree.MemberReference):
                            arg_values.append(arg.member)
                        elif isinstance(arg, javalang.tree.Literal):
                            arg_values.append(arg.value)
                        else:
                            arg_values.append(str(arg))
                    args_found.append(arg_values)
    return args_found

# %%
#Finds the type of mapping using keywords
def find_mapping_type(lang1, lang2, code1, code2):
    code1 = code1.lower()
    code2 = code2.lower()

    if lang1 == lang2:
        return "Direct"

    jni_indicators = [
        "native", "system.loadlibrary", "jnienv", "jni_onload",
        "jniexport", "jnicall", "findclass", "getmethodid"
    ]
    if ("java" in [lang1, lang2]) and (
        any(indicator in code1 for indicator in jni_indicators)
        or any(indicator in code2 for indicator in jni_indicators)
    ):
        return "JNI Mapping"

# %%
import pandas as pd
layer_map = analyze_call_layers(repo_call_chain)
records = []

#Uses edges in the call chain to generate the
for func1_full, called_funcs in repo_call_chain.items():
    file1, func1 = func1_full.split(":")
    code1 = code_dict[file1]
    lang1 = "python" if file1.endswith(".py") else "java"
    func1_code = extract_function_code(code1, func1, lang1)

    for func2 in called_funcs:
        file2 = next((fname.split(":")[0] for fname in repo_call_chain if fname.endswith(":" + func2)), "unknown")
        code2 = code_dict.get(file2, "")
        lang2 = "python" if file2.endswith(".py") else "java"
        func2_code = extract_function_code(code2, func2, lang2)

        if lang1 == "python":
            args_list = arguments_from_python(code1, func1, func2)
        else:
            args_list = arguments_from_java(code1, func1, func2)

        records.append({
            "function1_name": func1,
            "function2_name": func2,
            "file_name_function1": file1,
            "file_name_function2": file2,
            "parameter_passed": args_list,
            "level_of_abstraction_function1": layer_map.get(func1_full, "Unknown"),
            "level_of_abstraction_function2": layer_map.get(
                next((fname for fname in repo_call_chain if fname.endswith(":" + func2)), "unknown"),
                "Unknown"
            ),
            "mapping_type" : find_mapping_type(lang1, lang2, func1_code, func2_code),
            "code_function1": func1_code,
            "code_function2": func2_code
        })

df = pd.DataFrame(records)
csv_path = "call_chain_links.csv"
df.to_csv(csv_path, index=False, sep=",")

display(df.head())
# Out:
#   function1_name        function2_name        file_name_function1  \
# 0       onCreate  openOrCreateDatabase  SQLInjectionActivity.java
# 1       onCreate           mDB.execSQL  SQLInjectionActivity.java
# 2       onCreate           mDB.execSQL  SQLInjectionActivity.java
# 3       onCreate           mDB.execSQL  SQLInjectionActivity.java
# 4       onCreate           mDB.execSQL  SQLInjectionActivity.java
#
#   file_name_function2                parameter_passed  \
# 0             unknown  [["sqli", MODE_PRIVATE, null]]
# 1             unknown                              []
# 2             unknown                              []
# 3             unknown                              []
# 4             unknown                              []
#
#   level_of_abstraction_function1 level_of_abstraction_function2 mapping_type  \
# 0              Mid-level (Logic)                        Unknown       Direct
# 1              Mid-level (Logic)                        Unknown       Direct
# 2              Mid-level (Logic)                        Unknown       Direct
# 3              Mid-level (Logic)                        Unknown       Direct
# 4              Mid-level (Logic)                        Unknown       Direct
#
#                                       code_function1 code_function2
# 0  onCreate(Bundle savedInstanceState) {\n       ...
# 1  onCreate(Bundle savedInstanceState) {\n       ...
# 2  onCreate(Bundle savedInstanceState) {\n       ...
# 3  onCreate(Bundle savedInstanceState) {\n       ...
# 4  onCreate(Bundle savedInstanceState) {\n       ...
